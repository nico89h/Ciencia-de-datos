# %%
import seaborn as sns

# Cargas (loadings): cuánto aporta cada variable original a cada componente principal
loadings = pca.components_.T  # transpuesta para que cada fila sea una variable

# Variables originales
features = X.columns

# Graficamos los vectores para los primeros 2 componentes (para poder verlos en 2D)
plt.figure(figsize=(10,8))

for i, feature in enumerate(features):
    plt.arrow(0, 0,             # origen
              loadings[i,0],    # componente 1
              loadings[i,1],    # componente 2
              color='r', alpha=0.7, head_width=0.02)
    plt.text(loadings[i,0]*1.1, loadings[i,1]*1.1, feature, color='b', ha='center', va='center')

plt.xlabel("Componente Principal 1")
plt.ylabel("Componente Principal 2")
plt.title("Biplot de PCA (vectores de variables sobre CP1 y CP2)")
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.show()

# Extra: heatmap de los 6 primeros componentes
plt.figure(figsize=(12,6))
sns.heatmap(loadings[:, :6], annot=True, cmap="coolwarm", xticklabels=[f"PC{i+1}" for i in range(6)], yticklabels=features)
plt.title("Cargas de las variables en los primeros 6 componentes principales")
plt.xlabel("Componentes principales")
plt.ylabel("Variables originales")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import seaborn as sns
#       3 # Cargas (loadings): cuánto aporta cada variable original a cada componente principal
# ----> 4 loadings = pca.components_.T  # transpuesta para que cada fila sea una variable
#       6 # Variables originales
#       7 features = X.columns
#
# NameError: name 'pca' is not defined
